# %%
import pandas as pd

# csv, excel, html and sql can be imported into pd
# need:
    # sqlalchemy
    # lxml
    # html5lib
    # BeautifulSoup4

df = pd.read_csv('example.csv') # convert to csv dataframe
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
# write state as csv, don't save indices as column to avoid dupe index column
df.to_csv('example_output.csv', index=False)

# %%
# read excel
# diff excel sheets are diff dataframes

df = pd.read_excel('Excel_Sample.xlsx', sheet_name='Sheet1')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
# write to it like csv
df.to_excel('Excel_Sample2.xlsx', sheet_name='new sheet')

# %%
# can directly read html tables
# works with table html elements
data = pd.read_html("https://www.fdic.gov/bank/individual/failed/banklist.html")
data
# Out:
# [                               Bank Name               City         State  \
#  0                   Pulaski Savings Bank            Chicago      Illinois
#  1     The First National Bank of Lindsay            Lindsay      Oklahoma
#  2  Republic First Bank dba Republic Bank       Philadelphia  Pennsylvania
#  3                          Citizens Bank           Sac City          Iowa
#  4               Heartland Tri-State Bank            Elkhart        Kansas
#  5                    First Republic Bank      San Francisco    California
#  6                         Signature Bank           New York      New York
#  7                    Silicon Valley Bank        Santa Clara    California
#  8                      Almena State Bank             Almena        Kansas
#  9             First City Bank of Florida  Fort Walton Beach       Florida
#
#      Cert                 Aquiring Institution      Closing Date  \
#  0  28611                      Millennium Bank  January 17, 2025
# ...

# %%
data[0]
# Out:
#                                Bank Name               City         State  \
# 0                   Pulaski Savings Bank            Chicago      Illinois
# 1     The First National Bank of Lindsay            Lindsay      Oklahoma
# 2  Republic First Bank dba Republic Bank       Philadelphia  Pennsylvania
# 3                          Citizens Bank           Sac City          Iowa
# 4               Heartland Tri-State Bank            Elkhart        Kansas
# 5                    First Republic Bank      San Francisco    California
# 6                         Signature Bank           New York      New York
# 7                    Silicon Valley Bank        Santa Clara    California
# 8                      Almena State Bank             Almena        Kansas
# 9             First City Bank of Florida  Fort Walton Beach       Florida
#
#     Cert                 Aquiring Institution      Closing Date  \
# 0  28611                      Millennium Bank  January 17, 2025
# ...

# %%
# pandas isn't the best way to read sql, since there are many different engines (postgres, etc.)
# need individual libraries to load them, look up on a need-basis
# example for sqlite

from sqlalchemy import create_engine

engine = create_engine('sqlite:///:memory:') # init mini sqlite database in memory

# %%
# create new table from db in local sql db
# first arg is name of table, 2nd is minidb/engien
df.to_sql('my_table', engine)
# Out:
# 4

# %%
# read sql into dataframe like this
sqldf = pd.read_sql('my_table', con=engine)
sqldf
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15

# %%
# FINALLY DONE W FUCKING PANDAS
